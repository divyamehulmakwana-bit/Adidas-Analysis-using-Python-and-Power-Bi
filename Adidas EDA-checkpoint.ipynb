# %% [markdown]
# # Exploratory Data Analysis on Adidas Sales Dataset

# %% [markdown]
# **Adidas Sales Dataset – Summary**
#
# This dataset contains transactional-level sales data for Adidas products across different regions and retailers. It captures both revenue and profitability details, enabling analysis from multiple perspectives (time, geography, product, retailer, and sales channel).

# %% [markdown]
# **Problem Statement**
#
# Adidas, as a global sportswear brand, generates sales across multiple regions, retailers, and sales channels. However, without structured analysis, it is difficult to identify which regions, products, and retailers drive the most revenue and profit, and how different sales methods (online, offline, distributor) impact performance.
#
# This project aims to perform Exploratory Data Analysis (EDA) on Adidas sales data to uncover trends, measure profitability, and highlight actionable insights that can guide business decisions on product focus, regional strategies, and channel optimization.

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# installing plotly
# !pip install plotly
import plotly
import plotly.express as px

import plotly.io as pio
pio.renderers.default = "notebook_connected"

# for map visuals
# !pip install us
import us

# %%
plt.rcParams['axes.facecolor'] = '#f9f9f9'   # background of plotting area
plt.rcParams['figure.facecolor'] = 'white'   # background of the whole figure
plt.rcParams['axes.edgecolor'] = 'black'     # border color

# %%
#importing the dataset

df = pd.read_excel('Adidas Sales Data.xlsx')
df.sample(5)
# Out:
#          Retailer  Retailer ID Region        State            City  \
# 6409       Kohl's      1197831  South     Oklahoma   Oklahoma City
# 4961       Kohl's      1185732   West      Wyoming        Cheyenne
# 4607    West Gear      1185732   West         Utah  Salt Lake City
# 4960       Kohl's      1185732   West      Wyoming        Cheyenne
# 5197  Foot Locker      1185732  South  Mississippi         Jackson
#
#      Gender Type   Product Category  Price per Unit  Units Sold  Total Sales  \
# 6409         Men    Street Footwear              23         133         3059
# 4961       Women            Apparel              37         165         6105
# 4607         Men  Athletic Footwear              30         550       165000
# 4960         Men            Apparel              47         126         5922
# 5197         Men  Athletic Footwear              40         450       180000
#
#       Operating Profit  Operating Margin Sales Method Transaction Date
# ...

# %%
# Shape of the Dataset

print(f"The Shape of the Dataset is {df.shape}")
print(f"No of Rows {df.shape[0]}")
print(f"No of Columns {df.shape[1]}")
# Out:
# The Shape of the Dataset is (9648, 14)
# No of Rows 9648
# No of Columns 14

# %%
#checking for missing values

df.isna().sum()
# Out:
# Retailer            0
# Retailer ID         0
# Region              0
# State               0
# City                0
# Gender Type         0
# Product Category    0
# Price per Unit      0
# Units Sold          0
# Total Sales         0
# Operating Profit    0
# Operating Margin    0
# Sales Method        0
# Transaction Date    0
# dtype: int64

# %%
#checking for duplicates

df.duplicated().sum()
# Out:
# 0

# %%
# checking for descriptive statistics

df.describe(include = 'all')
# Out:
#            Retailer   Retailer ID Region       State      City Gender Type  \
# count          9648  9.648000e+03   9648        9648      9648        9648
# unique            6           NaN      5          50        52           2
# top     Foot Locker           NaN   West  California  Portland         Men
# freq           2637           NaN   2448         432       360        4826
# mean            NaN  1.173850e+06    NaN         NaN       NaN         NaN
# min             NaN  1.128299e+06    NaN         NaN       NaN         NaN
# 25%             NaN  1.185732e+06    NaN         NaN       NaN         NaN
# 50%             NaN  1.185732e+06    NaN         NaN       NaN         NaN
# 75%             NaN  1.185732e+06    NaN         NaN       NaN         NaN
# max             NaN  1.197831e+06    NaN         NaN       NaN         NaN
# std             NaN  2.636038e+04    NaN         NaN       NaN         NaN
#
# ...

# %%
#checking the datatypes and non-null counts of the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   object
#  1   Retailer ID       9648 non-null   int64
#  2   Region            9648 non-null   object
#  3   State             9648 non-null   object
#  4   City              9648 non-null   object
#  5   Gender Type       9648 non-null   object
#  6   Product Category  9648 non-null   object
#  7   Price per Unit    9648 non-null   int64
#  8   Units Sold        9648 non-null   int64
#  9   Total Sales       9648 non-null   int64
#  10  Operating Profit  9648 non-null   float64
#  11  Operating Margin  9648 non-null   float64
#  12  Sales Method      9648 non-null   object
#  13  Transaction Date  9648 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(4), object(7)
# memory usage: 1.0+ MB

# %%
#checking for unique values

df.nunique()
# Out:
# Retailer               6
# Retailer ID            4
# Region                 5
# State                 50
# City                  52
# Gender Type            2
# Product Category       3
# Price per Unit        94
# Units Sold           361
# Total Sales         3138
# Operating Profit    5618
# Operating Margin      66
# Sales Method           3
# Transaction Date     724
# dtype: int64

# %%
# adding a new column called product which is gender + product category

df['Product'] = df['Gender Type'] + " " + df['Product Category']
df['Product'].head(5)
# Out:
# 0              Men Apparel
# 1            Women Apparel
# 2      Men Street Footwear
# 3    Men Athletic Footwear
# 4    Women Street Footwear
# Name: Product, dtype: object

# %%
# starting with analysis

# %% [markdown]
# # **Overview**

# %%
#starting off with some basic kpis

# %%
#total revenue generated

print(f"The Total Revenue Generated is $ {df['Total Sales'].sum():,}")
# Out:
# The Total Revenue Generated is $ 899,902,125

# %%
# Total Operating Profit

print(f"The Total Revenue Generated is $ {df['Operating Profit'].sum():,.2f}")
# Out:
# The Total Revenue Generated is $ 332,134,761.45

# %%
# Total Quantity Purchased

print(f"The Total Revenue Generated is {df['Units Sold'].sum():,}")
# Out:
# The Total Revenue Generated is 2,478,861

# %%
# Average Operating Margin

print(f"The Average Operating Margin is {df['Operating Margin'].mean()*100:.2f}%")
# Out:
# The Average Operating Margin is 42.30%

# %%
# Total Transactions

print(f"The Total Transactions are {df['Operating Margin'].value_counts().sum()}")
# Out:
# The Total Transactions are 9648

# %%
# Average Selling Price

print(f"The Average Selling Price is $ {df['Total Sales'].sum()/df['Units Sold'].sum():.2f}")
# Out:
# The Average Selling Price is $ 363.03

# %%
# now moving to visuals

# %%
# Revenue Generated by Products
revenue_by_products = df.groupby('Product')['Total Sales'].sum().reset_index()
revenue_by_products

plt.figure(figsize= (12,8))
ax = sns.barplot(x = 'Product',y = 'Total Sales', data = revenue_by_products,color = "#78B3D4")

for container in ax.containers:
    ax.bar_label(container, fmt='%.0f', label_type='edge', fontsize=10, color='black')
    
plt.title("Total Revenue by Products")
plt.xticks(rotation = 90)
plt.show()

# %%
# Revenue Generated by Region
revenue_by_regions = df.groupby('Region')['Total Sales'].sum().reset_index()
revenue_by_regions

plt.figure(figsize= (12,8))
ax = sns.barplot(x = 'Region',y = 'Total Sales', data = revenue_by_regions,color = "#78B3D4")

for container in ax.containers:
    ax.bar_label(container, fmt='%.0f', label_type='edge', fontsize=10, color='black')

# total operating profit by region
profit_by_regions = df.groupby('Region')['Operating Profit'].sum().reset_index()
profit_by_regions

sns.lineplot(data = profit_by_regions, x= 'Region', y = 'Operating Profit', color = 'lightgray')
    
plt.title("Total Revenue by Regions & Operating Profit")
plt.xticks(rotation = 90)
plt.show()

# %%
#adding a year-month col for timeline
df['Year-Month'] = df['Transaction Date'].dt.year.astype(str) + "-" + df['Transaction Date'].dt.month.astype(str)

df['Year-Month'] = pd.to_datetime(df['Year-Month'], format='%Y-%m')

# %%
# Revenue overtime

revenue_over_years = df.groupby('Year-Month')['Total Sales'].sum().reset_index()

plt.figure(figsize= (12,5))
sns.lineplot(data = revenue_over_years,x = 'Year-Month',y = 'Total Sales', color = '#78B3D4', linestyle="--",marker = "o")
plt.title("Total Revenue Over the Months")
plt.xticks(rotation = 90)
plt.show()

# %%
#Total Revenue by Category

revenue_by_cat = df.groupby("Product Category")['Total Sales'].sum().reset_index()
revenue_by_cat

plt.figure(figsize= (8,5))
colors = ["#C5C5C5","#DAE8F1","#78B3D4"]
plt.pie(revenue_by_cat['Total Sales'],labels = revenue_by_cat['Product Category'],autopct= "%1.1f%%",colors=colors)
plt.title("Total Revenue by Region")
plt.show()

# %%
#Total Revenue by Sales Method

revenue_by_sales_method = df.groupby("Sales Method")['Total Sales'].sum().reset_index()
revenue_by_cat

plt.figure(figsize= (8,5))
colors = ["#C5C5C5","#DAE8F1","#78B3D4"]
plt.pie(revenue_by_sales_method['Total Sales'],labels = revenue_by_sales_method['Sales Method'],autopct= "%1.1f%%",colors=colors)
plt.title("Total Revenue by Sales Method")
plt.show()

# %% [markdown]
# # regional Analysis

# %%
#before making the kpis lets calculate some fields

#profit by State
profit_by_state = df.groupby('State')['Operating Profit'].sum().reset_index()
profit_by_state

profit_by_states = profit_by_state.sort_values(by = 'Operating Profit', ascending = False,ignore_index = True)
profit_by_states.head()
# Out:
#             State  Operating Profit
# 0        New York       23329824.07
# 1         Florida       20926206.92
# 2      California       19301170.40
# 3           Texas       18688204.35
# 4  South Carolina       11324236.39

# %%
#profit by City
profit_by_city = df.groupby('City')['Operating Profit'].sum().reset_index()
profit_by_city

profit_by_cities = profit_by_city.sort_values(by = 'Operating Profit', ascending = False,ignore_index = True)
profit_by_cities.head()
# Out:
#             City  Operating Profit
# 0     Charleston       15607190.11
# 1       New York       13899973.16
# 2          Miami       12168619.11
# 3       Portland       10760799.37
# 4  San Francisco       10256249.56

# %%
#profit by Region
profit_by_region = df.groupby('Region')['Operating Profit'].sum().reset_index()
profit_by_region

profit_by_regions = profit_by_region.sort_values(by = 'Operating Profit', ascending = False,ignore_index = True)
profit_by_regions.head()
# Out:
#       Region  Operating Profit
# 0       West       89609406.55
# 1  Northeast       68020587.65
# 2      South       61138004.07
# 3  Southeast       60555416.70
# 4    Midwest       52811346.48

# %% [markdown]
# # KPIS

# %%
# Best performing State by Profit
print(f'The Best Performing State by Profit is {profit_by_states.iloc[0,0]} with Profit of ${profit_by_states.iloc[0,1]:,.2f}')
# Out:
# The Best Performing State by Profit is New York with Profit of $23,329,824.07

# %%
# Best performing City by Profit
print(f'The Best Performing City by Profit is {profit_by_cities.iloc[0,0]} with Profit of ${profit_by_cities.iloc[0,1]:,.2f}')
# Out:
# The Best Performing City by Profit is Charleston with Profit of $15,607,190.11

# %%
# Best performing Region by Profit
print(f'The Best Performing Region by Profit is {profit_by_regions.iloc[0,0]} with Profit of ${profit_by_regions.iloc[0,1]:,.2f}')
# Out:
# The Best Performing Region by Profit is West with Profit of $89,609,406.55

# %%
#average revenue by state
avg_rev_by_state = df['Total Sales'].sum() / df['State'].nunique()
print(f'The Average Revenue By State is ${avg_rev_by_state:,.2f} ')
# Out:
# The Average Revenue By State is $17,998,042.50

# %%
#state with most most quantity purchased

quant_by_state = df.groupby('State')['Units Sold'].sum().reset_index()
quant_by_states = quant_by_state.sort_values(by = 'Units Sold', ascending = False, ignore_index = True)
print(f'The state with most most quantity purchased is {quant_by_states.iloc[0,1]:,} Units')
# Out:
# The state with most most quantity purchased is 169,140 Units

# %%
#state with most most  transactions
transactions_by_state = df.groupby('State')['Total Sales'].count().reset_index().head(10)
#renaming Colummns
transactions_by_state.rename(columns = {"Total Sales":"Total Transactions"},inplace = True)

# %%
transactions_by_states = transactions_by_state.sort_values(by = 'Total Transactions',ascending = False,ignore_index= True)
print(f'The State with most transactions is {transactions_by_states.iloc[0,0]} with a total of {transactions_by_states.iloc[0,1]:,} Transactions')
# Out:
# The State with most transactions is Texas with a total of 432 Transactions

# %% [markdown]
# # Visuals

# %%
# total revenue and quantity purchased by regions

#Revenue by Region
revenue_by_region = df.groupby('Region')['Total Sales'].sum().reset_index().sort_values(by = 'Total Sales', ascending = False,ignore_index = True)

# Quantity Purchased by Region
quant_by_region = df.groupby('Region')['Units Sold'].sum().reset_index().sort_values(by = 'Units Sold', ascending = False,ignore_index = True)

# %%
plt.figure(figsize = (12,8))
ax = sns.barplot(data = revenue_by_region, x = 'Region',y = 'Total Sales',color = "#78B3D4")
for container in ax.containers:
    ax.bar_label(container = container,label = 'Total Sales',fmt='{:,.0f}')

ax2 = ax.twinx()
sns.lineplot(data =quant_by_region,x = 'Region',y = 'Units Sold' ,color = "lightgray",linestyle ="--",marker = "o",linewidth = 2)

plt.title("Total Revenue and Units Sold by Region")
plt.show()

# %%
# top 10 cities by revenue
rev_by_city = df.groupby('City')['Total Sales'].sum().reset_index().sort_values(by = "Total Sales",ascending =  False,ignore_index = True).head(10)

profit_by_city = df.groupby('City')['Operating Profit'].sum().reset_index().sort_values(by = "Operating Profit",ascending =  False,ignore_index = True).head(10)

# To ensure both have same city order
merged = rev_by_city.merge(profit_by_city, on="City")

fig,ax = plt.subplots(figsize = (12,8))

ax.barh(data = merged, y = merged['City'],width = merged["Total Sales"],color = "#78B3D4")
ax.set_xlabel("Total Revenue",color = "#78B3D4")
ax.tick_params(colors = "#78B3D4")

ax2 = ax.twiny()
sns.lineplot(data = merged,x = 'Operating Profit',y = 'City',color = "lightgray",linestyle ="--",marker = "o",linewidth = 2)
ax2.set_xlabel("Operating Profit",color = "gray")
ax2.tick_params(colors = "gray")

plt.title("Top 10 Cities by Total Revenue(Bar) & Total Profit(line) ")
plt.show()

# %%
# a map to show transactions per state
#creating a new column so that we can create a map

df['State abb'] = df['State'].apply(lambda x:us.states.lookup(x).abbr)

# %%
#transactions by states
transactions_by_states = df.groupby('State abb')['Total Sales'].count().reset_index()
transactions_by_states.rename(columns = {'Total Sales':'Total Transactions'},inplace = True)


fig = px.choropleth(data_frame = transactions_by_states,
                    locations='State abb',color='Total Transactions',
                    color_continuous_scale='Blues',scope = 'usa',
                    labels=['State abb','Total Trancations'],
                   locationmode='USA-states',
                   title="Total Transactions by State")
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# revenue by states

revenue_by_states = df.groupby('State abb')['Total Sales'].sum().reset_index()



fig = px.choropleth(data_frame = revenue_by_states,
                    locations='State abb',color='Total Sales',
                    color_continuous_scale='Blues',scope = 'usa',
                    labels=['State abb','Total Sales'],
                   locationmode='USA-states',
                   title="Total Revenue by State")
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# units sold by states

units_sold_by_states = df.groupby('State abb')['Units Sold'].sum().reset_index()



fig = px.choropleth(data_frame = units_sold_by_states,
                    locations='State abb',color='Units Sold',
                    color_continuous_scale='Blues',scope = 'usa',
                    labels=['State abb','Units Sold'],
                   locationmode='USA-states',
                   title="Units Sold by State")
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Product Analysis

# %%
# lets make some Kpis

# %%
#Total Products
print(f'There are a Total of {df["Product"].nunique()} Products')
# Out:
# There are a Total of 6 Products

# %%
# Total Product Categories
print(f'There are a Total of {df["Product Category"].nunique()} Categories')
# Out:
# There are a Total of 3 Categories

# %%
#most popular product category
units_sold_by_category = df.groupby('Product Category')['Units Sold'].sum().reset_index().sort_values(by ="Units Sold",ascending = False,ignore_index = True)

print(f'The most popular product category is {units_sold_by_category.iloc[0,0]} with {units_sold_by_category.iloc[0,1]:,.0f} Units Sold.')
# Out:
# The most popular product category is Street Footwear with 985,589 Units Sold.

# %%
# most popular product for each category

#creating a table for Footwear
Street_Footwear = df[df['Product Category'] == "Street Footwear"]

units_Street_Footwear = Street_Footwear.groupby('Product')['Units Sold'].sum().reset_index().sort_values(by ="Units Sold",ascending = False,ignore_index = True)
print(f'The most popular product in Street Footwear is {units_Street_Footwear.iloc[0,0]} with {units_Street_Footwear.iloc[0,1]:,.0f} Units Sold.')
# Out:
# The most popular product in Street Footwear is Men Street Footwear with 593,320 Units Sold.

# %%
#creating a table for Athletic Footwear

Athletic_Footwear = df[df['Product Category'] == "Athletic Footwear"]

units_Athletic_Footwear = Athletic_Footwear.groupby('Product')['Units Sold'].sum().reset_index().sort_values(by ="Units Sold",ascending = False,ignore_index = True)
print(f'The most popular product in Athletic Footwear is {units_Athletic_Footwear.iloc[0,0]} with {units_Athletic_Footwear.iloc[0,1]:,.0f} Units Sold.')
# Out:
# The most popular product in Athletic Footwear is Men Athletic Footwear with 435,526 Units Sold.

# %%
#creating a table for Athletic Footwear

Apparel = df[df['Product Category'] == "Apparel"]

units_Apparel = Apparel.groupby('Product')['Units Sold'].sum().reset_index().sort_values(by ="Units Sold",ascending = False,ignore_index = True)
print(f'The most popular product in Apparel is {units_Apparel.iloc[0,0]} with {units_Apparel.iloc[0,1]:,.0f} Units Sold.')
# Out:
# The most popular product in Apparel is Women Apparel with 433,827 Units Sold.

# %%
#most Profitable Product

product_profit = df.groupby('Product')['Operating Profit'].sum().reset_index().sort_values(by = 'Operating Profit',ascending = False,ignore_index = True)
print(f'The most Profitable product  is {product_profit.iloc[0,0]} with an Operating Profit of ${product_profit.iloc[0,1]:,.2f}')
# Out:
# The most Profitable product  is Men Street Footwear with an Operating Profit of $82,802,260.62

# %%
# total transactions sold for Gender specific products
gender_based_transactions = df.groupby('Gender Type').size().reset_index(name='Total Transactions')
print(f'Total Transactions for Men Centric products was {gender_based_transactions.iloc[0,1]}')
print(f'Total Transactions for Women Centric products was {gender_based_transactions.iloc[1,1]}')
# Out:
# Total Transactions for Men Centric products was 4826
# Total Transactions for Women Centric products was 4822

# %% [markdown]
# # Visuals

# %%
# Total Transactions by Product Category
transactions_by_category = df.groupby('Product Category').size().reset_index(name='Total Transactions')
colors = ["#C5C5C5","#DAE8F1","#78B3D4"]
plt.pie(x = transactions_by_category['Total Transactions'],labels=transactions_by_category['Product Category'],colors=colors,autopct="%1.2f%%")
plt.title("Total Transactions by Products")
plt.show()

# %%
# Total units sold by Gender
units_sold_by_gender = df.groupby('Gender Type')['Units Sold'].sum().reset_index()
colors = ["#C5C5C5","#78B3D4"]
plt.pie(x = units_sold_by_gender['Units Sold'],labels=units_sold_by_gender['Gender Type'],colors=colors,autopct="%1.2f%%")
plt.title("Units Sold by Gender Type")
plt.show()

# %%
# total Revenue by Products
rev_by_products = df.groupby('Product')['Total Sales'].sum().reset_index().sort_values(by = 'Total Sales',ascending = False,ignore_index = True)

plt.figure(figsize = (12,8))
plt.barh(y = rev_by_products['Product'],width = rev_by_products['Total Sales'],color = "#78B3D4")
plt.xlabel('Total Sales')
plt.ylabel('Products')
plt.title('Total Revenue by Products')
plt.show()

# %%
# making a scatter plot to see the relationship between various factors

product_data = df.groupby('Product')[['Total Sales','Units Sold','Operating Profit','Operating Margin']].agg({"Total Sales":"sum","Units Sold":"sum","Operating Profit":"sum","Operating Margin":"mean"}).reset_index()
product_data
# Out:
#                    Product  Total Sales  Units Sold  Operating Profit  \
# 0              Men Apparel    123728632      306683       44763030.33
# 1    Men Athletic Footwear    153673680      435526       51846888.19
# 2      Men Street Footwear    208826244      593320       82802260.62
# 3            Women Apparel    179038860      433827       68650970.56
# 4  Women Athletic Footwear    106631896      317236       38975784.94
# 5    Women Street Footwear    128002813      392269       45095826.81
#
#    Operating Margin
# 0          0.413225
# 1          0.402702
# 2          0.446130
# 3          0.441318
# 4          0.424359
# 5          0.410199

# %%
fig =px.scatter(product_data,x='Total Sales',y='Operating Profit',size='Units Sold',color ='Operating Margin',text = 'Product',color_continuous_scale='Blues' )
fig.update_traces(textfont_size=10, textposition="top center")
fig.update_layout(
    xaxis_title="Total Sales",
    yaxis_title="Operating Profit",
    legend_title="Margin"
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Retailer Analysis

# %%
#kpis

# %%
# total Retailers
print(f'There are a total of {df["Retailer"].nunique()} Retailers')
# Out:
# There are a total of 6 Retailers

# %%
#which retailer gets the most profit

profit_by_retailers = df.groupby('Retailer')['Operating Profit'].sum().reset_index().sort_values(by ='Operating Profit',ascending = False,ignore_index = True)
print(f'The Retailer that earns the most profit is {profit_by_retailers.iloc[0,0]} with a profit of ${profit_by_retailers.iloc[0,1]:,.2f} ')
# Out:
# The Retailer that earns the most profit is West Gear with a profit of $85,667,873.18

# %%
#which retailer sells the most units

units_by_retailers = df.groupby('Retailer')['Units Sold'].sum().reset_index().sort_values(by ='Units Sold',ascending = False,ignore_index = True)
print(f'The Retailer that sells the Most Units is {units_by_retailers.iloc[0,0]} with a total of {units_by_retailers.iloc[0,1]:,} Units Sold')
# Out:
# The Retailer that sells the Most Units is West Gear with a total of 625,262 Units Sold

# %%
#which retailer earns the most revenue

revenue_by_retailers = df.groupby('Retailer')['Total Sales'].sum().reset_index().sort_values(by ='Total Sales',ascending = False,ignore_index = True)
print(f'The Retailer that earns the most revenue is {revenue_by_retailers.iloc[0,0]} with a revenue of ${revenue_by_retailers.iloc[0,1]:,.2f}')
# Out:
# The Retailer that earns the most revenue is West Gear with a revenue of $242,964,333.00

# %%
#which retailer most transactions

transactions_by_retailers = df.groupby('Retailer').size().reset_index(name = 'Total Transactions')
print(f'The Retailer with most Transactions is {transactions_by_retailers.iloc[0,0]} with a total of {transactions_by_retailers.iloc[0,1]:,} Transactions')
# Out:
# The Retailer with most Transactions is Amazon with a total of 949 Transactions

# %% [markdown]
# # Visuals

# %%
# profit by retailer and gender type
profit_by_gender_retailer = df.groupby(['Retailer','Gender Type'])['Operating Profit'].sum().reset_index()

plt.figure(figsize = (10,8))
sns.barplot(data = profit_by_gender_retailer,x = 'Retailer',y = 'Operating Profit',hue = 'Gender Type',palette = ["#DAE8F1","#78B3D4"])
plt.title("profit by retailer and gender type")
plt.show()

# %%
# units sold by retailer and gender type
units_by_gender_retailer = df.groupby(['Retailer','Gender Type'])['Units Sold'].sum().reset_index()

plt.figure(figsize = (10,8))
sns.barplot(data = units_by_gender_retailer,y = 'Retailer',x = 'Units Sold',hue = 'Gender Type',palette = ["#DAE8F1","#78B3D4"],orient='h')
plt.title("profit by retailer and gender type")
plt.show()

# %%
# since West Gear has consistently given good results lets deep dive into it

# %%
West_Gear = df[df['Retailer'] == "West Gear"]
West_Gear.sample(3)
# Out:
#        Retailer  Retailer ID     Region          State        City  \
# 9217  West Gear      1128299       West         Oregon    Portland
# 1892  West Gear      1185732  Northeast  West Virginia  Charleston
# 9366  West Gear      1128299       West         Oregon    Portland
#
#      Gender Type   Product Category  Price per Unit  Units Sold  Total Sales  \
# 9217         Men            Apparel              45         125        56250
# 1892       Women  Athletic Footwear              48          77         3696
# 9366       Women  Athletic Footwear              39          75         2925
#
#       Operating Profit  Operating Margin Sales Method Transaction Date  \
# 9217          22500.00              0.40     In-store       2021-02-24
# 1892           1884.96              0.51       Online       2021-07-16
# 9366           1082.25              0.37       Outlet       2021-03-23
#
#                       Product Year-Month
# 9217              Men Apparel 2021-02-01
# ...

# %%
# best performing products within west gear

wg_products = West_Gear.groupby('Product')['Units Sold'].sum().reset_index()

fig = px.bar(wg_products,x = 'Product',y = 'Units Sold', text = 'Units Sold',color_discrete_sequence=["#78B3D4"] )
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Revenue over time 
wg_rev_overtime = West_Gear.groupby('Year-Month')['Total Sales'].sum().reset_index()
px.line(wg_rev_overtime,x = 'Year-Month', y = 'Total Sales',color_discrete_sequence=["#78B3D4"] )
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Sales method distribution
wg_sales_method = West_Gear.groupby('Sales Method')['Total Sales'].sum().reset_index()

colors = ["#C5C5C5","#DAE8F1","#78B3D4"]
px.pie(wg_sales_method ,names = 'Sales Method', values = 'Total Sales',color_discrete_sequence = colors,hole = 0.7 )
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Sales Method Analysis

# %%
#kpis

# %%
# total Sales Method
print(f'There are a total of {df["Sales Method"].nunique()} Sales Method')
# Out:
# There are a total of 3 Sales Method

# %%
#which Sales Method gets the most profit

profit_by_SM = df.groupby('Sales Method')['Operating Profit'].sum().reset_index().sort_values(by ='Operating Profit',ascending = False,ignore_index = True)
print(f'The Sales Method that earns the most profit is {profit_by_SM.iloc[0,0]} with a profit of ${profit_by_SM.iloc[0,1]:,.2f} ')
# Out:
# The Sales Method that earns the most profit is In-store with a profit of $127,591,287.50

# %%
#which Sales Method sells the most units

units_by_SM = df.groupby('Sales Method')['Units Sold'].sum().reset_index().sort_values(by ='Units Sold',ascending = False,ignore_index = True)
print(f'The Sales Method that sells the Most Units is {units_by_SM.iloc[0,0]} with a total of {units_by_SM.iloc[0,1]:,} Units Sold')
# Out:
# The Sales Method that sells the Most Units is Online with a total of 939,093 Units Sold

# %%
#which Sales Method earns the most revenue

revenue_by_SM = df.groupby('Sales Method')['Total Sales'].sum().reset_index().sort_values(by ='Total Sales',ascending = False,ignore_index = True)
print(f'The Sales Method that earns the most revenue is {revenue_by_SM.iloc[0,0]} with a revenue of ${revenue_by_SM.iloc[0,1]:,.2f}')
# Out:
# The Sales Method that earns the most revenue is In-store with a revenue of $356,643,750.00

# %% [markdown]
# # Visuals

# %%
#Revenue Over time by Sales Method

revenue_by_SM = df.groupby(['Year-Month','Sales Method'])['Total Sales'].sum().reset_index()

colors = ["#C5C5C5","#78B3B6","#78B3D4"]
px.line(revenue_by_SM,x = 'Year-Month',y = 'Total Sales',color='Sales Method',markers= True,color_discrete_sequence = colors)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Transactions by Sales Methods

transactions_by_SM = df.groupby('Sales Method').size().reset_index(name = "Total Transactions")
colors = ["#C5C5C5","#DAE8F1","#78B3D4"]
px.pie(transactions_by_SM ,names = 'Sales Method', values = 'Total Transactions',color_discrete_sequence = colors,hole = 0.7 )
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Adidas Sales Data Analysis – Key Insights
#
# The analysis of the Adidas sales dataset provides a detailed understanding of the company’s performance across products, regions, retailers, and customer segments.
#
# Revenue & Profit Insights:
#
# Revenue is heavily concentrated in certain products and categories, with Men’s Street Footwear and Street Wear dominating sales and profitability.
#
# Operating profit trends closely follow revenue, indicating strong margin products are also top sellers.
#
# Significant growth is observed in certain periods, suggesting seasonal or promotional spikes, particularly in 2021.
#
# Product & Customer Segmentation:
#
# Sales are fairly balanced between male and female products, but Men’s products contribute slightly higher revenue.
#
# High-margin products tend to be concentrated in specific categories, offering opportunities for focused marketing and inventory strategies.
#
# Product performance varies across regions, suggesting regional preferences or retailer specialization.
#
# Regional & Retailer Insights:
#
# Certain states and cities contribute disproportionately to overall revenue, indicating strategic hubs for Adidas sales.
#
# Regional analysis shows that specific regions dominate revenue and unit sales, highlighting potential for targeted regional campaigns.
#
# Retailer performance varies significantly; top retailers generate most of the revenue and profit, while smaller retailers lag behind.
#
# Sales Channel Insights:
#
# Different sales methods (Online, Outlet, In-Store) show varying performance: In-Store generates the highest revenue, whereas Online drives higher transaction volume.
#
# Analyzing sales by channel helps identify which modes are most profitable versus which generate the most customer engagement.
#
# Overall Strategic Implications:
#
# The data highlights key products, regions, and channels that drive revenue and profit, providing actionable insights for inventory management, marketing strategies, and regional expansion.
#
# Balancing high-margin products with popular high-volume items can optimize overall profitability.
#
# Seasonal patterns suggest opportunities for promotional planning and targeted campaigns in peak months.
